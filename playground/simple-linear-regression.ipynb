# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('../datasets/Salary_Data.csv')

# %%
dataset.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
# so, our independent variable will be `YearsExperience` and dependent
# variable will be `Salary` for this example

X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# ## Taking care of missing data

# %% [markdown]
# There are no missing values for this dataset. Run `dataset.isna().sum()` for confirming.

# %% [markdown]
# ## Encoding the categorical data

# %% [markdown]
# There are no categorical variables for this dataset. Run `dataset.dtypes` for confirming.

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# ## Training the Simple Linear Regression model on the Training set

# %%
regressor = LinearRegression()
# fitting LinearRegression  instance on training data.
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Predicting the Test set results

# %%
y_hat = regressor.predict(X_test)

# %% [markdown]
# ## Visualizing the Training set results

# %%
y_train_hat = regressor.predict(X_train)
plt.scatter(X_train, y_train, color='red')
plt.plot(X_train, y_train_hat, color='blue')
plt.title('Salary vs Experience(Training set)')
plt.xlabel('Salary')
plt.ylabel('Years of Experience')
plt.show()

# %% [markdown]
# ## Visualizing the Test set results

# %%
plt.scatter(X_test, y_test, color='red')
plt.plot(X_test, y_hat, color='blue')
plt.title('Salary vs Experience(Test set)')
plt.xlabel('Salary')
plt.ylabel('Years of Experience')
plt.show()
